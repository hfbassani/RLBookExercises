# %% [markdown]
# In Example 4.1, if ${\pi}$ is the equiprobable random policy, what is $q_\pi(11, down)$?
# What is $q_\pi(7, down)$?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Considerado que após a ação de $q_\pi(11, down)$ ser tomada, ele irá para posição terminal então receberá uma recompensa de -1 e o jogo irá finalizar. Então $q_\pi(11, down) = -1$. No caso de $q_\pi(7, down)$ ser feita, como $R_t = -1$, dado que o valor esperado da recompensa dada uma ação é $q_*(a) = E[R_t|A_t=a]$, então:
#
# $q_\pi(7, down) = E[R_t|A_t=a]$
#
# $q_\pi(7, down) = R_t + \gamma * E[R_t|S_t = s, A_t=a] $

# %% [markdown]
# Utilizando a informação da tabela a seguir
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Temos $q_\pi(7, down) = -1 + 1 * -14 => -15 $
